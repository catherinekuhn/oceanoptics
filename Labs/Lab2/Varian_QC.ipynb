# %%
# This notebook was built in Catherine's root environment. (Sorry Don!) 
import pandas as pd
from pandas import DataFrame
import numpy as np
import os
import glob
import datetime
import pylab
import matplotlib as plt
import datetime as datetime  
import statsmodels.api as sm  
import matplotlib.pyplot as plt
import seaborn as sns
# plt.style.use('ggplot')
# Out:
# /Users/ckuhn/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
# %matplotlib inline

# %%
# %cd /Users/ckuhn/Downloads/
# Out:
# /Users/ckuhn/Downloads

# %%
data = pd.read_csv('group1a_test.csv', low_memory=False)

# %%
data.columns
# Out:
# Index([u'wl_a', u'acs17_g1a_diw_aside_242_1', u'acs17_g1a_diw_aside_248_2',
#        u'acs17_g1a_DREfil_aside_208_1', u'acs17_g1a_DREfil_aside_227_2',
#        u'acs17_g1a_DREtot_aside_208_1'],
#       dtype='object')

# %%
#sns.lmplot('acs17_g1a_diw_aside_242_1', 'acs17_g1a_diw_aside_248_2', data=data, fit_reg=False)

sns.set_context("talk", font_scale=4)
#sns.set_context("talk", rc={"lines.linewidth": 2})

plt.rcParams['font.size'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams['legend.fontsize'] = 20
#plt.rcParams['figure.titlesize'] = 18

#def set_style():
   # plt.style.use(['seaborn-white', 'seaborn-talk'])
   # plt.rc("font", family="Times New Roman")
      
sns.set_style('white')

#plt.title('Absorption Coefficient for Blank')


Y1 = (data['acs17_g1a_diw_aside_242_1'])
Y2 = (data['acs17_g1a_diw_aside_248_2'])
x = data['wl_a']

plt.scatter(x,Y1, color = 'grey', marker = '>')
plt.scatter(x,Y2,color='k', marker = 'o')
plt.xlim(400,750)

plt.xlabel('Wavelength (nm)')
plt.ylabel('Absorption (m-1)')

plt.legend(scatterpoints=1, loc='best')
plt.show()

# %%
data = pd.read_csv('group1a_cside.csv', low_memory=False)

# %%
data.columns
# Out:
# Index([u'wl_c', u'acs17_g1a_diw_cside_236_1', u'acs17_g1a_diw_cside_252_2',
#        u'acs17_g1a_DREfil_cside_208_1', u'acs17_g1a_DREfil_cside_208_2',
#        u'acs17_g1a_DREtot_cside_208_1', u'acs17_g1a_DREtot_cside_232_2',
#        u'acs17_g1a_DREtot_cside_232_3'],
#       dtype='object')

# %%
#sns.lmplot('acs17_g1a_diw_aside_242_1', 'acs17_g1a_diw_aside_248_2', data=data, fit_reg=False)

#sns.set_context("talk", font_scale=4)
#sns.set_context("talk", rc={"lines.linewidth": 2})

plt.rcParams['font.size'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams['legend.fontsize'] = 20
plt.rcParams['figure.titlesize'] = 24

#def set_style():
   # plt.style.use(['seaborn-white', 'seaborn-talk'])
   # plt.rc("font", family="Times New Roman")
      
sns.set_style('white')

#plt.title('c for Blank')

Y1 = (data['acs17_g1a_diw_cside_236_1'])
Y2 = (data['acs17_g1a_diw_cside_252_2'])
x = data['wl_c']

plt.scatter(x,Y1, color = 'grey', marker = '>')
plt.scatter(x,Y2,color='k', marker = 'o')
plt.xlim(400,750)

plt.xlabel('Wavelength (nm)')
plt.ylabel('c (m-1)')

plt.legend(scatterpoints=1, loc='best')
plt.show()

# %%
data = pd.read_csv('theboss.csv', low_memory=False)

# %%
data.columns
# Out:
# Index([u'awavelength', u'cwavelength', u'a_ts_filtered', u'c_ts_filtered',
#        u'b_ts_filtered', u'a_sv_filtered', u'a_uncorr_filtered',
#        u'a_flat_filtered', u'a_ts_total', u'c_ts_total', u'b_ts_total',
#        u'a_sv_total', u'a_uncorr_total', u'a_flat_total', u'Unnamed: 14',
#        u'Unnamed: 15', u'Unnamed: 16', u'Unnamed: 17', u'Unnamed: 18',
#        u'Unnamed: 19', u'Unnamed: 20', u'Unnamed: 21', u'Unnamed: 22',
#        u'Unnamed: 23', u'Unnamed: 24', u'Unnamed: 25', u'Unnamed: 26',
#        u'Unnamed: 27', u'Unnamed: 28', u'Unnamed: 29', u'Unnamed: 30',
#        u'Unnamed: 31', u'Unnamed: 32', u'Unnamed: 33', u'Unnamed: 34',
#        u'Unnamed: 35', u'Unnamed: 36', u'Unnamed: 37', u'Unnamed: 38',
#        u'Unnamed: 39', u'Unnamed: 40', u'Unnamed: 41', u'Unnamed: 42',
#        u'Unnamed: 43', u'Unnamed: 44', u'Unnamed: 45', u'Unnamed: 46',
#        u'Unnamed: 47', u'Unnamed: 48', u'Unnamed: 49', u'Unnamed: 50',
# ...

# %%
#sns.lmplot('acs17_g1a_diw_aside_242_1', 'acs17_g1a_diw_aside_248_2', data=data, fit_reg=False)

#sns.set_context("talk", font_scale=4)
#sns.set_context("talk", rc={"lines.linewidth": 2})

plt.rcParams['font.size'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams['legend.fontsize'] = 20
plt.rcParams['figure.titlesize'] = 24

#def set_style():
   # plt.style.use(['seaborn-white', 'seaborn-talk'])
   # plt.rc("font", family="Times New Roman")
      
sns.set_style('white')

#plt.title('c for Blank')

Y0 = (data['a_ts_filtered']) # this is the temperature corrected for the filtered
Y1 = (data['a_ts_total']) # this is the t corrected for the total

Y2 = (data['a_flat_filtered']) # this is the spectrally flat correction for the total
Y3 = (data['a_flat_total'])   # this is the spectrally flat for the filtered

x = data['awavelength']

plt.scatter(x,Y0, color = '#67001f', marker = 'o')
plt.scatter(x,Y1, color = '#053061', marker = 'o')

plt.scatter(x,Y2, color = '#67001f', marker = '*')
plt.scatter(x,Y3,color= '#053061', marker = '>')

plt.xlim(400,750)

plt.xlabel('Wavelength (nm)')
plt.ylabel('c (m-1)')

plt.legend(scatterpoints=1, loc='best')
plt.show()

# %%
#sns.lmplot('acs17_g1a_diw_aside_242_1', 'acs17_g1a_diw_aside_248_2', data=data, fit_reg=False)

#sns.set_context("talk", font_scale=4)
#sns.set_context("talk", rc={"lines.linewidth": 2})

plt.rcParams['font.size'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams['legend.fontsize'] = 20
plt.rcParams['figure.titlesize'] = 24

#def set_style():
   # plt.style.use(['seaborn-white', 'seaborn-talk'])
   # plt.rc("font", family="Times New Roman")
      
sns.set_style('white')

#plt.title('c for Blank')

Y0 = (data['a_ts_filtered']) # this is the temperature corrected for the filtered
Y1 = (data['a_ts_total']) # this is the t corrected for the total

Y2 = (data['a_sv_filtered']) # this is the spectrally flat correction for the total
Y3 = (data['a_sv_total'])   # this is the spectrally flat for the filtered

x = data['awavelength']

plt.scatter(x,Y0, color = '#ef8a62', marker = 'd')
plt.scatter(x,Y1, color = '#053061', marker = 'o')

plt.scatter(x,Y2, color = '#ef8a62', marker = '*')
plt.scatter(x,Y3,color= '#053061', marker = '>')

plt.xlim(400,750)

plt.xlabel('Wavelength (nm)')
plt.ylabel('c (m-1)')

plt.legend(scatterpoints=1, loc='best')
plt.show()

# %%
ap = pd.read_csv('./ACS_017/ap.csv', low_memory=False)

# %%
ap.columns
# Out:
# Index([u'cwavelength', u'ap_scatering', u'ap_ts', u'ap_flat'], dtype='object')

# %%
#sns.lmplot('acs17_g1a_diw_aside_242_1', 'acs17_g1a_diw_aside_248_2', data=data, fit_reg=False)

#sns.set_context("talk", font_scale=4)
#sns.set_context("talk", rc={"lines.linewidth": 2})

plt.rcParams['font.size'] = 20
plt.rcParams['axes.labelsize'] = 20
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams['legend.fontsize'] = 20
plt.rcParams['figure.titlesize'] = 24

#def set_style():
   # plt.style.use(['seaborn-white', 'seaborn-talk'])
   # plt.rc("font", family="Times New Roman")
      
sns.set_style('white')

#plt.title('c for Blank')

Y0 = (ap['ap_ts']) 
Y1 = (ap['ap_flat']) 
Y2 = (ap['ap_scatering']) 
x= (ap['cwavelength']) 

plt.scatter(x, Y0, color = '#67001f', marker = 'o')
plt.scatter(x, Y1, color = '#053061', marker = 'o')
plt.scatter(x, Y2, color = '#6baed6', marker = 'o')

plt.xlim(400,750)

plt.xlabel('Wavelength (nm)')
plt.ylabel('a part (m-1)')

#plt.legend(scatterpoints=1, loc='best')
plt.show()

# %%
def set_style():
    plt.style.use(['seaborn-white', 'seaborn-talk'])
    plt.rc("font", family="Times New Roman")
set_style()

x = data['a_flat_filtered']
y = data['a_flat_total']
colors = data['awavelength']
plt.scatter(x, y, c=colors, cmap='rainbow')
plt.colorbar(label = 'Wavelength (nm)')

plt.xlabel('Flat-Corrected Absorption Filtered (m-1)')
plt.ylabel('Flat-Corrected Absorption Total (m-1)')

plt.show()

# %%
def set_style():
    plt.style.use(['seaborn-white', 'seaborn-talk'])
    plt.rc("font", family="Times New Roman")
set_style()

x = data['a_sv_filtered']
y = data['a_sv_total']
colors = data['awavelength']
plt.scatter(x, y, c=colors, cmap='rainbow')
plt.colorbar(label = 'CO2 ppm')

plt.xlabel('Variable-Corrected Absorption Filtered (m-1)')
plt.ylabel('Variable-Corrected Absorption Total (m-1)')

plt.show()

# %%
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
predict_y = intercept + slope * x
x = data['a_sv_filtered']
y = data['a_sv_total']

plt.plot(x,y,'go')
plt.plot(x, predict_y, 'k-')
plt.legend(('data', 'line-regression'), 'upper left')
plt.autoscale(True)
plt.grid(True)
plt.show()
# Out:
# /Users/ckuhn/anaconda2/lib/python2.7/site-packages/matplotlib/legend.py:634: UserWarning: Legend does not support 'data' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#using-proxy-artist
#   "#using-proxy-artist".format(orig_handle)
# /Users/ckuhn/anaconda2/lib/python2.7/site-packages/matplotlib/legend.py:634: UserWarning: Legend does not support 'line-regression' instances.
# A proxy artist may be used instead.
# See: http://matplotlib.org/users/legend_guide.html#using-proxy-artist
#   "#using-proxy-artist".format(orig_handle)
